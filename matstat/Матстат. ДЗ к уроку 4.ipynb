# %% [markdown]
# # ДЗ №4

# %% [markdown]
# ## Задание 1
# Случайная непрерывная величина A имеет равномерное распределение на промежутке (200, 800].
#
#     Найдите ее среднее значение и дисперсию.
#
# $M(X) = \frac{a + b}{2}$
#
# $D(X) = \frac{(b - a)^2}{12}$

# %% [markdown]
# $M(X) = \frac{200 + 800}{2} = 500 $
#
# $D(X) = \frac{(800 - 200)^2}{12} = 30000 $

# %% [markdown]
# ## Задание 2
# О случайной непрерывной равномерно распределенной величине B известно, что ее дисперсия равна 0.2.
#
#     Можно ли найти правую границу величины B и ее среднее значение зная, что левая граница равна 0.5?
#     Если да, найдите ее.

# %% [markdown]
# $M(X) = \frac{a + b}{2} = ?$
#
# $b = \,?$
#
# ---
#
# $D(X) = \frac{(b - a)^2}{12} = 0.2$

# %% [markdown]
# $(b-a)^2 = 12 * 0.2 = 2.4$

# %% [markdown]
# $b - a = \sqrt{2.4} ≈ 1,55$

# %% [markdown]
# $b = 1.55 + a = 1.55 + 0.5 = 2.05$

# %% [markdown]
# $M(X) = \frac{0.5 + 2.05}{2} = 1.275$

# %% [markdown]
# ## Задание 3
# Непрерывная случайная величина X распределена нормально и задана плотностью распределения
#
# $f(x) = \frac{1}{4 \sqrt{2  \pi}} \cdot e^{-\frac{(x+2)^2}{32}}$
#
# $f(x) = \frac{1}{\sigma \sqrt{2 \pi}} \cdot e^{- \frac{(x - a)^2}{2 \sigma^2}}$
#
#     Найдите:
#         а). M(X)
#         б). D(X)
#         в). std(X) (среднее квадратичное отклонение)

# %% [markdown]
# $M(X) = 2$
#
# $D(X) = 16$
#
# $std(X) = \sigma = 4$

# %% [markdown]
# ## Задание 4
# Рост взрослого населения города X имеет нормальное распределение.
# Причем, средний рост равен 174 см, а среднее квадратичное отклонение равно 8 см.
#
#     Какова вероятность того, что случайным образом выбранный взрослый человек имеет рост:
#         а). больше 182 см
#         б). больше 190 см
#         в). от 166 см до 190 см
#         г). от 166 см до 182 см
#         д). от 158 см до 190 см
#         е). не выше 150 см или не ниже 190 см
#         ё). не выше 150 см или не ниже 198 см
#         ж). ниже 166 см.

# %% [markdown]
# $M(X) = 174$
#
# $D(X) = 64$
#
# $\sigma(Х) = 8$

# %% [markdown]
#     а). больше 182 см – (182-174)/8 = 1 (0.8413);
#         1 - 0.8413 = 0.1587
# ---
#     б). больше 190 см – (190-174)/8 = 2 (0,9772);
#         1 - 0,9772 = 0,0228
# ---
#     в). от 166 см до 190 см – (166 - 174)/8 = -1 (0,1587);
#                               (190 - 174)/8 = 2 (0,9772);
#         0,9772 - 0,1587 = 0,8185
# ---
#     г). от 166 см до 182 см – (166 - 174)/8 = -1 (0,1587);
#                               (182 - 174)/8 = 1 (0,8413);
#         0,8413 - 0,1587 = 0,6826
# ---
#     д). от 158 см до 190 см – (158 - 174)/8 = -2 (0,0228);
#                               (190 - 174)/8 = 2 (0,9772);
#         0,9772 - 0,0228 = 0,9544
# ---
#     е). не выше 150 см или не ниже 190 см – (150 - 174)/8 = -3 (0,0013);
#                                             (190 - 174)/8 = 2 (0,9772);
#         0.0013 + (1 - 0,9772) = 0,0241
#
# ---
#     ё). не выше 150 см или не ниже 198 см – (150 - 174)/8 = -3 (0,0013);
#                                             (198 - 174)/8 = 3 (0,9987);
#         0,0013 * 2 = 0,0026
#
# ---
#     ж). ниже 166 см. – (166 - 174)/8 = -1 (0,1587);
#         0,1587

# %% [markdown]
# ## Задание 5
# На сколько сигм (средних квадратичных отклонений) отклоняется рост человека, равный 190 см, от
# математического ожидания роста в популяции, в которой M(X) = 178 см и D(X) = 25 кв.см?

# %% [markdown]
# $M(X) = 178$
#
# $D(X) = 25$
#
# $\sigma(Х) = 5$

# %% [markdown]
# $(190 - 178)/5 = 2.4$
